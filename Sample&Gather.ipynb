# %%
import os

# %%
import pandas as pd

# %%
# %%time
data=pd.read_csv('transactions.csv')
# Out:
# CPU times: user 30.5 s, sys: 3.21 s, total: 33.7 s
# Wall time: 34.1 s

# %%
data
# Out:
#                                                   msno  payment_method_id  \
# 0         YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1         AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2         UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3         M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4         yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
# 5         KN7I82kjY0Tn76Ny95ncqBUVbO7b8AXrOPqZutKpxIM=                 21
# 6         m5ptKif9BjdUghHXXomSezy5ohJiHm85PE13f/3kQaw=                 39
# 7         uQxbyACsPOEkTIrv9jZgoGXelGBW81ZsSZKy9fhj5Z8=                 39
# 8         LUPRfoE2r3WwVWhYO/TqQhjrL/qP6CO+/ORUlr7yNc0=                 39
# 9         pMVjPLgVknaJYm9L0xUwxA2jmhpK7gfhGnsmmwX1mrE=                 39
# 10        bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=                 39
# 11        TZVCT9pCufI/AWjrG9s2fLbkpDI/8jRDAI6+PfQmTDs=                 39
# ...

# %%
# %%time 
msno=pd.DataFrame(data.msno.unique())
# Out:
# CPU times: user 7.18 s, sys: 242 ms, total: 7.43 s
# Wall time: 7.5 s

# %% [markdown]
# Set index on the above field

# %%
# %%time
data.set_index('msno')
# Out:
# CPU times: user 963 ms, sys: 530 ms, total: 1.49 s
# Wall time: 1.52 s
#                                               payment_method_id  \
# msno
# YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
# KN7I82kjY0Tn76Ny95ncqBUVbO7b8AXrOPqZutKpxIM=                 21
# m5ptKif9BjdUghHXXomSezy5ohJiHm85PE13f/3kQaw=                 39
# uQxbyACsPOEkTIrv9jZgoGXelGBW81ZsSZKy9fhj5Z8=                 39
# LUPRfoE2r3WwVWhYO/TqQhjrL/qP6CO+/ORUlr7yNc0=                 39
# pMVjPLgVknaJYm9L0xUwxA2jmhpK7gfhGnsmmwX1mrE=                 39
# bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=                 39
# TZVCT9pCufI/AWjrG9s2fLbkpDI/8jRDAI6+PfQmTDs=                 39
# ...

# %%
msno.sample(frac=0.25,random_state=99)
# Out:
#                                                     0
# 2199426  TY/c+vOKivJdlZ6ZWoTydwM3W4GdZfGm0yYp2Xptwig=
# 1213778  zxDIdffX6rqr9UpKB2l/wJU6fQ6AWh/0MV4qrZOA3B4=
# 897473   i4ikAi/XHxZbisZa0MIo2rnAw4WTA1GWIpq2nMHBEDg=
# 1975356  NFw8X9z9BmlRBNVpt7FhbtJnuHp9ZUcELDtDPhQ5naE=
# 872676   5j3EskezM8f4VMSQA17VEj8JNRikqypLM9z7cu0wqAY=
# 879511   s0vURC4ZkANnJcDeTMm/LkMYbRH+Dp+bfARBSluHzeo=
# 1976697  v6dQsb+rXxDgZzacGrrFqbBgPhhnsr+pmUm15eMeAKQ=
# 2097919  rYVj/RgtzywcoTTaVOvucNBVC9l5sPkCkJjTC1mSPwk=
# 1541458  F7f4AJpTTfGmkheYsyFENNWHMkOw4uaU7y3ky6IjIvU=
# 1472239  P0kR3dwLDt3NuZpqX2Pf6oNBElLfh2spX+7W/zJiQBo=
# 2186454  H0FiYojQS1eaACCpY5HmOEILYGUUu4aLeAV5BFzWfuU=
# 194794   HvivBR+cW5rSozWKJjzEGwiBg3xhz5pxS0yKAwKtxdw=
# 1099087  qyCnxlK0CCVMTFz/eNOJcbQH6II7iHf03wJPputR3sg=
# 672859   2nKA2YuAM8cSjKsVUPoZaYxP4F/coVO8C/htquFVByw=
# 2356821  KP2dKgoLxu5LU9bS3TxOp+/ysWuVxm8qQrRegViYEdM=
# 31234    Z6yH/66wSUF8hpeFu05TjM6sxAgoOy/qcKI+mNaMLJg=
# ...

# %% [markdown]
# Selecting records from above set

# %%
# %%time
records = data.loc[data['msno'].isin(msno.values)]
# Out:
# CPU times: user 1min 31s, sys: 1.26 s, total: 1min 33s
# Wall time: 1min 30s

# %%
records
# Out:
#                                                   msno  payment_method_id  \
# 0         YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1         AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2         UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3         M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4         yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
# 5         KN7I82kjY0Tn76Ny95ncqBUVbO7b8AXrOPqZutKpxIM=                 21
# 6         m5ptKif9BjdUghHXXomSezy5ohJiHm85PE13f/3kQaw=                 39
# 7         uQxbyACsPOEkTIrv9jZgoGXelGBW81ZsSZKy9fhj5Z8=                 39
# 8         LUPRfoE2r3WwVWhYO/TqQhjrL/qP6CO+/ORUlr7yNc0=                 39
# 9         pMVjPLgVknaJYm9L0xUwxA2jmhpK7gfhGnsmmwX1mrE=                 39
# 10        bQkbrEPdMfVfdsoz0RoWSmgYpHJuhRqtIml7aRUrFL8=                 39
# 11        TZVCT9pCufI/AWjrG9s2fLbkpDI/8jRDAI6+PfQmTDs=                 39
# ...
